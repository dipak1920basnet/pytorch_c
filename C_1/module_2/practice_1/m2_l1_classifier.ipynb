# %%
import torch
import torch.optim as optim 
import torchvision
from torchvision.transforms import transforms
from torch.utils.data import dataloader
import matplotlib.pyplot as plt

# %%
from build_model import SimpleMNISTDNN

# %%
# Choose a device to run 

# choose gpu 
if torch.cuda.is_available():
    device = torch.device("cuda")
    print("cuda")
# choose for apple gpu 
elif torch.backends.mps.is_available():
    device = torch.device("mps")
    print("mps")
else:
    device = torch.device("cpu")
    print("cpu")
# Out:
# cuda

# %%
import torch

print("Torch:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("CUDA version:", torch.version.cuda)
print("GPU count:", torch.cuda.device_count())
# Out:
# Torch: 2.11.0+cu128
# CUDA available: True
# CUDA version: 12.8
# GPU count: 1

# %%
import sys
import torch

print(sys.executable)
print(torch.__version__)
print(torch.__file__)
# Out:
# C:\Users\dipak\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe
# 2.10.0+cpu
# C:\Users\dipak\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\__init__.py
